# %%
import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys = get_keys("/home/tj/Documents/Flatiron/yelpAPI/.secret/yelp_api.json")
api_key = keys['api_key']

# %%
import requests
term = 'Mexican'
location = 'Astoria NY'
SEARCH_LIMIT = 10

url = 'https://api.yelp.com/v3/businesses/search'

headers = {'Authorization' : 'Bearer {}' .format(api_key)}

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }

response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "YFL1rAdlv7J0cswHVhvCtQ", "alias": "ruta-oaxaca-mexican-cuisine-astoria-3", "name": "Ruta Oaxaca Mexican Cuisine", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/_5Z0dN4pp9jauOsUVhkwvQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/ruta-oaxaca-mexican-cuisine-astoria-3?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg", "review_count": 244, "categories": [{"alias": "mexican", "title": "Mexican"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}, {"alias": "cocktailbars", "title": "Cocktail Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.76058, "longitude": -73.92182}, "transactions": ["delivery", "pickup"], "price": "$$$", "location": {"address1": "35-03 Broadway", "address2": null, "address3": "", "city": "Astoria", "zip_code": "11106", "country": "US", "state": "NY", "display_address": ["35-03 Broadway", "Astoria, NY 11106"]}, "phone": "+192

# %%
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
for key in response.json().keys():
    print(key)
    value = response.json()[key] # standard dictionary formating
    print(type(value)) # the dtype
    print('\n') # separate out data
# Out:
# businesses
# <class 'list'>
#
#
# total
# <class 'int'>
#
#
# region
# <class 'dict'>

# %%
# previewing the data
response.json()['businesses'][:-2]
# Out:
# [{'id': 'YFL1rAdlv7J0cswHVhvCtQ',
#   'alias': 'ruta-oaxaca-mexican-cuisine-astoria-3',
#   'name': 'Ruta Oaxaca Mexican Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_5Z0dN4pp9jauOsUVhkwvQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ruta-oaxaca-mexican-cuisine-astoria-3?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg',
#   'review_count': 244,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.76058, 'longitude': -73.92182},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '35-03 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['35-03 Broadway', 'Astoria, NY 11106']},
#   'phone': '+19293491228',
#   'display_phone': '(929) 349-1228',
#   'distance': 705.1752335083106},
#  {'id': 'AUyKmFjpaVLwc3awfUnqgQ',
#   'alias': 'chela-and-garnacha-astoria',
#   'name': 'Chela & Garnacha',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vFWyi2m1qjn7LoGdpHnmjQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chela-and-garnacha-astoria?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg',
#   'review_count': 433,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7556474, 'longitude': -73.9274415},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '33-09 36th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['33-09 36th Ave', 'Astoria, NY 11106']},
#   'phone': '+19178326876',
#   'display_phone': '(917) 832-6876',
#   'distance': 1308.046071413852},
#  {'id': '6AJwsgXr7YwsqneGVAdgzw',
#   'alias': 'las-catrinas-mexican-bar-and-eatery-astoria',
#   'name': 'Las Catrinas Mexican Bar & Eatery',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IdeVcvGtxqk7dj0_l_3W3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/las-catrinas-mexican-bar-and-eatery-astoria?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg',
#   'review_count': 447,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7614214682633,
#    'longitude': -73.9246649456171},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '32-02 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32-02 Broadway', 'Astoria, NY 11106']},
#   'phone': '+19177450969',
#   'display_phone': '(917) 745-0969',
#   'distance': 642.5257707161409},
#  {'id': 'U8JnmnLw8WhQ3GV4zD2Yow',
#   'alias': 'don-camote-cantina-mexicana-astoria',
#   'name': 'Don Camote Cantina Mexicana',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3qVKALaXcTu2mNWr0fCVxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/don-camote-cantina-mexicana-astoria?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg',
#   'review_count': 10,
#   'categories': [{'alias': 'newmexican', 'title': 'New Mexican Cuisine'},
#    {'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.76017, 'longitude': -73.92045},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '31-86 37th Street',
#    'address2': None,
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11103',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['31-86 37th Street', 'Astoria, NY 11103']},
#   'phone': '+13475310129',
#   'display_phone': '(347) 531-0129',
#   'distance': 771.3335708896755},
#  {'id': 'jzVv_21473lAMYXIhVbuTA',
#   'alias': 'de-mole-astoria-astoria',
#   'name': 'De Mole Astoria',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ydAsU1lYjsOPkeb_Lbowiw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/de-mole-astoria-astoria?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg',
#   'review_count': 414,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7625999, 'longitude': -73.9129028},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4220 30th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11103',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4220 30th Ave', 'Astoria, NY 11103']},
#   'phone': '+17187771655',
#   'display_phone': '(718) 777-1655',
#   'distance': 915.60744589032},
#  {'id': 'zNcDCPiUsE5aT6jyaCVtmA',
#   'alias': 'frescos-cantina-long-island-city',
#   'name': "Fresco's Cantina",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ULBZSvQH5riJuDUVZVF9Gw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/frescos-cantina-long-island-city?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg',
#   'review_count': 291,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.76837, 'longitude': -73.93303},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '12-14 31st Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Long Island City',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['12-14 31st Ave', 'Long Island City, NY 11106']},
#   'phone': '+13478087338',
#   'display_phone': '(347) 808-7338',
#   'distance': 927.5507063098299},
#  {'id': 'yvva7IYpD6J7OfKlCdQrkw',
#   'alias': 'mi-espiguita-taqueria-astoria',
#   'name': 'Mi Espiguita Taqueria',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8opIyE4AL8CUDZ1k3Lr3eQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mi-espiguita-taqueria-astoria?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg',
#   'review_count': 144,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7612033639422,
#    'longitude': -73.9261436462402},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '32-44 31st St',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32-44 31st St', 'Astoria, NY 11106']},
#   'phone': '+17187775648',
#   'display_phone': '(718) 777-5648',
#   'distance': 714.301080232381},
#  {'id': '6rM-N1SBbKPC7DWZNg5awQ',
#   'alias': 'los-portales-astoria-2',
#   'name': 'Los Portales',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mBfmIGVjtAy_3tYa4JhLZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/los-portales-astoria-2?adjust_creative=q9QcalLzp2Ap69V8CYwBOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q9QcalLzp2Ap69V8CYwBOg',
#   'review_count': 317,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7631768211379,
#    'longitude': -73.9282260153443},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '2508 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11105',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2508 Broadway', 'Astoria, NY 11105']},
#   'phone': '+17182046736',
#   'display_phone': '(718) 204-6736',
#   'distance': 654.4521994969878}]

# %%
response.json()['total']
# Out:
# 790

# %%
response.json()['region']
# Out:
# {'center': {'longitude': -73.92219543457031, 'latitude': 40.76688875374591}}

# %%
# our intrest is the businesses

import pandas as pd

df = pd.DataFrame.from_dict(response.json()['businesses'])

# no of rows
print(len(df))

# column names
print(df.columns)

# preview
df.head()
# Out:
# 10
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'coordinates', 'transactions', 'price',
#        'location', 'phone', 'display_phone', 'distance'],
#       dtype='object')
#                        id                                        alias
# 0  YFL1rAdlv7J0cswHVhvCtQ        ruta-oaxaca-mexican-cuisine-astoria-3  \
# 1  AUyKmFjpaVLwc3awfUnqgQ                   chela-and-garnacha-astoria
# 2  6AJwsgXr7YwsqneGVAdgzw  las-catrinas-mexican-bar-and-eatery-astoria
# 3  U8JnmnLw8WhQ3GV4zD2Yow          don-camote-cantina-mexicana-astoria
# 4  jzVv_21473lAMYXIhVbuTA                      de-mole-astoria-astoria
#
#                                 name
# 0        Ruta Oaxaca Mexican Cuisine  \
# 1                   Chela & Garnacha
# 2  Las Catrinas Mexican Bar & Eatery
# 3        Don Camote Cantina Mexicana
# 4                    De Mole Astoria
#
#                                            image_url  is_closed
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/_5Z0dN...      False  \
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/vFWyi2...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/IdeVcv...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/3qVKAL...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/ydAsU1...      False
#
#                                                  url  review_count
# 0  https://www.yelp.com/biz/ruta-oaxaca-mexican-c...           244  \
# 1  https://www.yelp.com/biz/chela-and-garnacha-as...           433
# 2  https://www.yelp.com/biz/las-catrinas-mexican-...           447
# 3  https://www.yelp.com/biz/don-camote-cantina-me...            10
# 4  https://www.yelp.com/biz/de-mole-astoria-astor...           414
#
#                                           categories  rating
# 0  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5  \
# 1  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 2  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 3  [{'alias': 'newmexican', 'title': 'New Mexican...     5.0
# 4         [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
#
#                                          coordinates        transactions
# 0     {'latitude': 40.76058, 'longitude': -73.92182}  [delivery, pickup]  \
# 1  {'latitude': 40.7556474, 'longitude': -73.9274...  [delivery, pickup]
# 2  {'latitude': 40.7614214682633, 'longitude': -7...  [delivery, pickup]
# 3     {'latitude': 40.76017, 'longitude': -73.92045}  [delivery, pickup]
# 4  {'latitude': 40.7625999, 'longitude': -73.9129...  [delivery, pickup]
#
#   price                                           location         phone
# 0   $$$  {'address1': '35-03 Broadway', 'address2': Non...  +19293491228  \
# 1    $$  {'address1': '33-09 36th Ave', 'address2': '',...  +19178326876
# 2    $$  {'address1': '32-02 Broadway', 'address2': '',...  +19177450969
# 3   NaN  {'address1': '31-86 37th Street', 'address2': ...  +13475310129
# 4    $$  {'address1': '4220 30th Ave', 'address2': '', ...  +17187771655
#
#     display_phone     distance
# 0  (929) 349-1228   705.175234
# 1  (917) 832-6876  1308.046071
# 2  (917) 745-0969   642.525771
# 3  (347) 531-0129   771.333571
# 4  (718) 777-1655   915.607446
